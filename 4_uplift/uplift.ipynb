# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    recency  history  used_discount  used_bogo   zip_code  is_referral channel  \
# 0       10   142.44              1          0  Surburban            0   Phone
# 1        6   329.08              1          1      Rural            1     Web
# 2        7   180.65              0          1  Surburban            1     Web
# 3        9   675.83              1          0      Rural            1     Web
# 4        2    45.34              1          0      Urban            0     Web
#
#              offer  conversion
# 0  Buy One Get One           0
# 1         No Offer           0
# 2  Buy One Get One           0
# 3         Discount           0
# 4  Buy One Get One           0

# %%
data.rename(columns={'conversion':'target', 'offer':'treatment'}, inplace=True)

# %%
data[['treatment']].value_counts()
# Out:
# treatment
# Buy One Get One    21387
# Discount           21307
# No Offer           21306
# dtype: int64

# %%
data['treatment'] = data.treatment.apply(lambda i : 0 if i == 'No Offer' else 1)

# %%
data.head()
# Out:
#    recency  history  used_discount  used_bogo   zip_code  is_referral channel  \
# 0       10   142.44              1          0  Surburban            0   Phone
# 1        6   329.08              1          1      Rural            1     Web
# 2        7   180.65              0          1  Surburban            1     Web
# 3        9   675.83              1          0      Rural            1     Web
# 4        2    45.34              1          0      Urban            0     Web
#
#    treatment  target
# 0          1       0
# 1          0       0
# 2          1       0
# 3          1       0
# 4          1       0

# %%
data[['channel']].value_counts()
# Out:
# channel
# Web             28217
# Phone           28021
# Multichannel     7762
# dtype: int64

# %%
data = pd.get_dummies(data)
data = data.drop(columns=['zip_code_Urban','channel_Web'])

# %%
data.head()
# Out:
#    recency  history  used_discount  used_bogo  is_referral  treatment  target  \
# 0       10   142.44              1          0            0          1       0
# 1        6   329.08              1          1            1          0       0
# 2        7   180.65              0          1            1          1       0
# 3        9   675.83              1          0            1          1       0
# 4        2    45.34              1          0            0          1       0
#
#    zip_code_Rural  zip_code_Surburban  channel_Multichannel  channel_Phone
# 0               0                   1                     0              1
# 1               1                   0                     0              0
# 2               0                   1                     0              0
# 3               1                   0                     0              0
# 4               0                   0                     0              0

# %%
from sklearn.model_selection import train_test_split

# %%
data_train, data_test = train_test_split(data, test_size = 0.3)

# %%
data_train.shape, data_test.shape
# Out:
# ((44800, 11), (19200, 11))

# %%
X_train = data_train.drop(columns=['treatment', 'target'])
y_train = data_train[['target']]
treatment_train = data_train[['treatment']]

# %%
X_test = data_test.drop(columns=['treatment', 'target'])
y_test = data_test[['target']]
treatment_test = data_test[['treatment']]

# %%
from sklift.metrics import uplift_at_k
from sklift.viz import plot_uplift_preds
from sklift.models import SoloModel

from catboost import CatBoostClassifier

# %%
models_results = {
    'approach': [],
    'uplift@10%': [],
    'uplift@20%': []
}

# %% [markdown]
# 1.1 Одна модель с признаком коммуникации

# %%
N =20000
sm = SoloModel(  CatBoostClassifier(iterations=20, thread_count=2, random_state=42, silent=True))
sm = sm.fit(  X_train, y_train, treatment_train)

uplift_sm = sm.predict(X_test)

sm_score = uplift_at_k( y_true=y_test, uplift=uplift_sm, treatment=treatment_test, strategy='by_group', k=0.1)
sm_score_2 = uplift_at_k( y_true=y_test, uplift=uplift_sm, treatment=treatment_test, strategy='by_group', k=0.2)

models_results['approach'].append('SoloModel')
models_results['uplift@10%'].append(sm_score)
models_results['uplift@20%'].append(sm_score_2)

# Получим условные вероятности выполнения целевого действия при взаимодействии для каждого объекта
sm_trmnt_preds = sm.trmnt_preds_
# И условные вероятности выполнения целевого действия без взаимодействия для каждого объекта
sm_ctrl_preds = sm.ctrl_preds_

# %% [markdown]
# 1.2 Трансформация классов

# %%
from sklift.models import ClassTransformation


ct = ClassTransformation(CatBoostClassifier(iterations=20, thread_count=2, random_state=42, silent=True))
ct = ct.fit(X_train, y_train, treatment_train)

uplift_ct = ct.predict(X_test)

ct_score = uplift_at_k(y_true=y_test, uplift=uplift_ct, treatment=treatment_test, strategy='by_group', k=0.1)
ct_score_2 = uplift_at_k(y_true=y_test, uplift=uplift_ct, treatment=treatment_test, strategy='by_group', k=0.2)

models_results['approach'].append('ClassTransformation')
models_results['uplift@10%'].append(ct_score)
models_results['uplift@20%'].append(ct_score_2)
# Out:
# <ipython-input-19-a61fdf906194>:5: UserWarning: It is recommended to use this approach on treatment balanced data. Current sample size is unbalanced.
#   ct = ct.fit(X_train, y_train, treatment_train)

# %%
X_train
# Out:
#        recency  history  used_discount  used_bogo  is_referral  \
# 22993        1   233.93              1          0            1
# 18572       10   159.89              0          1            1
# 37156        3    29.99              1          0            0
# 19152        7    89.05              1          0            0
# 9266         2    29.99              1          0            1
# ...        ...      ...            ...        ...          ...
# 6622         3   231.23              1          0            1
# 37232        6   379.62              1          1            0
# 4234         2   274.61              1          1            0
# 13300        1   301.67              0          1            0
# 17912       12    29.99              0          1            1
#
#        zip_code_Rural  zip_code_Surburban  channel_Multichannel  channel_Phone
# 22993               0                   1                     1              0
# 18572               0                   1                     0              1
# 37156               0                   1                     0              1
# 19152               0                   1                     0              1
# 9266                0                   1                     0              1
# ...               ...                 ...                   ...            ...
# 6622                0                   0                     0              0
# 37232               0                   0                     1              0
# 4234                0                   1                     1              0
# 13300               0                   1                     0              1
# 17912               0                   0                     0              1
#
# [44800 rows x 9 columns]

# %% [markdown]
# 2.1 Две независимые модели

# %%
from sklift.models import TwoModels


tm = TwoModels(  
    estimator_trmnt=CatBoostClassifier(iterations=10, random_state=42, silent=True), 
    estimator_ctrl=CatBoostClassifier(iterations=10, random_state=42, silent=True), 
    method='vanilla'
)
tm = tm.fit(X_train, y_train, treatment_train)

uplift_tm = tm.predict(X_test)

tm_score = uplift_at_k(y_true=y_test, uplift=uplift_tm, treatment=treatment_test, strategy='by_group', k=0.1)
tm_score_2 = uplift_at_k(y_true=y_test, uplift=uplift_tm, treatment=treatment_test, strategy='by_group', k=0.2)

models_results['approach'].append('TwoModels')
models_results['uplift@10%'].append(tm_score)
models_results['uplift@20%'].append(tm_score_2)

# %% [markdown]
# Построим табичку с результатами

# %%
pd.DataFrame(data=models_results).sort_values('uplift@10%', ascending=False)
# Out:
#               approach  uplift@10%  uplift@20%
# 0            SoloModel    0.115229    0.096805
# 2            TwoModels    0.098264    0.087213
# 1  ClassTransformation    0.089464    0.076549

# %%
# !pip3 install causalml
# Out:
# Requirement already satisfied: causalml in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (50.3.1.post20201107)
# Requirement already satisfied: numpy<1.19.0,>=0.16.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (1.18.5)
# Requirement already satisfied: xgboost in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (1.4.2)
# Requirement already satisfied: keras in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (2.4.3)
# Requirement already satisfied: pygam in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (0.8.0)
# Requirement already satisfied: lightgbm in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (3.1.1)
# Requirement already satisfied: packaging in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (20.4)
# Requirement already satisfied: tqdm in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (4.50.2)
# Requirement already satisfied: pandas>=0.24.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (1.1.3)
# Requirement already satisfied: tensorflow>=1.15.2 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (2.5.0)
# Requirement already satisfied: pyro-ppl in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (1.6.0)
# Requirement already satisfied: dill in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (0.3.4)
# Requirement already satisfied: shap<0.38.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (0.37.0)
# Requirement already satisfied: scikit-learn<0.24.0,>=0.22.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (0.23.2)
# Requirement already satisfied: matplotlib in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (3.3.2)
# Requirement already satisfied: pydotplus in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (2.0.2)
# Requirement already satisfied: torch in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (1.8.0)
# Requirement already satisfied: pip>=10.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (20.2.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (0.12.0)
# Requirement already satisfied: scipy==1.4.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (1.4.1)
# Requirement already satisfied: seaborn in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (0.11.0)
# Requirement already satisfied: Cython>=0.28.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from causalml) (0.29.21)
# Requirement already satisfied: pyyaml in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from keras->causalml) (5.3.1)
# Requirement already satisfied: h5py in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from keras->causalml) (2.10.0)
# Requirement already satisfied: future in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from pygam->causalml) (0.18.2)
# Requirement already satisfied: progressbar2 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from pygam->causalml) (3.53.1)
# Requirement already satisfied: wheel in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from lightgbm->causalml) (0.35.1)
# Requirement already satisfied: six in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from packaging->causalml) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from packaging->causalml) (2.4.7)
# Requirement already satisfied: pytz>=2017.2 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.1->causalml) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24.1->causalml) (2.8.1)
# Requirement already satisfied: tensorboard~=2.5 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (2.5.0)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (1.1.0)
# Requirement already satisfied: absl-py~=0.10 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (0.13.0)
# Requirement already satisfied: gast==0.4.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (2.5.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (2.5.0.dev2021032900)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (1.6.3)
# Requirement already satisfied: grpcio~=1.34.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (1.34.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (3.7.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (3.3.0)
# Requirement already satisfied: google-pasta~=0.2 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorflow>=1.15.2->causalml) (3.17.3)
# Requirement already satisfied: pyro-api>=0.1.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from pyro-ppl->causalml) (0.1.2)
# Requirement already satisfied: slicer==0.0.3 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from shap<0.38.1->causalml) (0.0.3)
# Requirement already satisfied: numba in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from shap<0.38.1->causalml) (0.51.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<0.24.0,>=0.22.0->causalml) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn<0.24.0,>=0.22.0->causalml) (0.17.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->causalml) (1.3.0)
# Requirement already satisfied: certifi>=2020.06.20 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->causalml) (2020.6.20)
# Requirement already satisfied: cycler>=0.10 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->causalml) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->causalml) (8.0.1)
# Requirement already satisfied: patsy>=0.5 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from statsmodels>=0.9.0->causalml) (0.5.1)
# Requirement already satisfied: python-utils>=2.3.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from progressbar2->pygam->causalml) (2.5.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow>=1.15.2->causalml) (1.32.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow>=1.15.2->causalml) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow>=1.15.2->causalml) (2.24.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow>=1.15.2->causalml) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow>=1.15.2->causalml) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow>=1.15.2->causalml) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.5->tensorflow>=1.15.2->causalml) (1.8.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from numba->shap<0.38.1->causalml) (0.34.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (4.7.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/maximcucer/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=1.15.2->causalml) (3.1.1)

# %%
from IPython.display import Image, display
from causalml.inference.tree import UpliftTreeClassifier
from causalml.inference.tree import uplift_tree_string, uplift_tree_plot

uplift_model = UpliftTreeClassifier(max_depth=4, min_samples_leaf=200, min_samples_treatment=50,
                                    n_reg=100, evaluationFunction='KL', control_name='control')

uplift_model.fit(X_train.values,
                 treatment=treatment_train.map({1: 'treatment1', 0: 'control'}).values,
                 y=y_train)

graph = uplift_tree_plot(uplift_model.fitted_uplift_tree, features)

# %%
import numpy as np
tree_lift =  np.array(uplift_model.predict(X_test.values))[0]

uplift_tree_30 = uplift_at_k(y_val, tree_lift, treat_val, strategy='overall')
print(f'uplift@30%: {uplift_tree_30:.4f}')
models_results['approach'].append('TreeModels')
models_results['uplift@30%'].append(uplift_tree_30)
